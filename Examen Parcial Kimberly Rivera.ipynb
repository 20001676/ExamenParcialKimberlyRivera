# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Universidad Galileo
# #### Kimberly Rivera - 20001676
#
#
# <h1><center>Examen Parcial de Ciencia de Datos en Python</center></h1>
#
# ## **Seccion Practica - (Programación y Sintaxis):**
#
# **Para	esta	serie	deberá	realizar	código	de	Python	para	solver	el	problema planteado,	deberá	usar	Jupyter	Lab	(Notebook)	para	resolver	elaborar	su código,	una	vez	finalizado	deberá	subir	el	notebook	donde trabajó.**
#
# * Desarrolle en Python un programa el cual genere un código alfa numérico de 7 letras mayusculas y 7 números entérelo, estos deben ser aleatorios, el código debe ser intercalado empezando por letras.
# * Su programa debe ejecutarse siempre y esperar la tecla enter para crear un código nuevo, el programa solo debe detenerse cuando el usuario ingrese la palabra exit en mayusculas o minúsculas o combinado.
# * Ademas de esto su programa debe separar todos los códigos que se generen en validos o no validos, un código se considera valido si la suma de los números que lo conforman es mayor a 30 y no es valido en caso contrario.
# * Si un código es valido, este debe almacenarse en un diccionario el cual contenga la suma de los números enteros como llave y el código como valor, note que en una ejecución se pueden crear varios códigos.
# * Por otro lado si el código no es valido, este deberá almacenarse en una lista.
# * Al momento de que el usuario ingrese exit, el programa deberá desplegar el contenido del diccionario de códigos validos y la lista de códigos no válidos.

# %%
import random
no_validos = []
resultado = ""
solonumeros = []
diccionario = {}
print("Bienvenidos al Examen Parcial 1 de Python...\nSi deseas crear un codigo presiona enter, si deseas salir del programa escribe exit.\nSi introduces cualquier otra información el programa se detendrá.")
entradaA = input()
entradaB = entradaA.lower()
if entradaB == 'exit':
  print('Has salido con éxito.')
else:
  while len(entradaB) != exit :
    solonumeros = []
    entradaB = entradaA.lower()
    if entradaB == "exit":
      print('\nHas solicitado salir del programa \nLos códigos válidos son:')
      print(diccionario)
      print('\nLos códigos no válidos son:')
      print(no_validos)
      print('\nHas salido con éxito.')
      break
    elif len(entradaA)== 0:
      for x in range(7):
        letra = random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz')
        resultado = resultado + str(letra)
        num = random.randint(0,9)
        resultado = resultado + str(num)
        solonumeros.append(num)
        sumatoria = sum(solonumeros)
      if sumatoria > 30 :
        print(resultado)
        diccionario[sumatoria] = resultado
      elif sumatoria < 30 :
        print(resultado)
        no_validos.append(resultado)
      resultado = ""
      sumatoria = 0
    elif entradaB != "exit" or len(entradaA) != 0:
      print('Información errónea')
      break
    entradaA = input()
# Out:
# Bienvenidos al Examen Parcial 1 de Python...
# Si deseas crear un codigo presiona enter, si deseas salir del programa escribe exit.
# Si introduces cualquier otra información el programa se detendrá.
#
# a9P8n8q9J8B4A4
#
#
# V5H3W1V3e8v8F6
#
# Z2R3q8b3L9t7b6
#
# B7I2k6i5i0d0K3
#
# d0y7V9I4q5n4q2
# EXit
#
# Has solicitado salir del programa
# Los códigos válidos son:
# {50: 'a9P8n8q9J8B4A4', 34: 'V5H3W1V3e8v8F6', 38: 'Z2R3q8b3L9t7b6', 31: 'd0y7V9I4q5n4q2'}
#
# Los códigos no válidos son:
# ['B7I2k6i5i0d0K3']
#
# Has salido con éxito.
